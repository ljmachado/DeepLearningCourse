# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'term', 'originated', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.349456
# Nearest to years: duarte, cic, parallelism, rafael, pests, motherboards, processions, submerged,
# Nearest to no: franchising, sten, ffts, hornet, fiendish, gravis, downgraded, volcanoes,
# Nearest to will: fable, grateful, baskerville, entrances, derived, barcodes, koza, gangrene,
# Nearest to may: tenn, ortho, nomad, mucous, joris, arctan, subroutine, mary,
# Nearest to and: nee, becquerel, bombard, monitored, confound, muir, baltimore, moth,
# Nearest to also: paleontological, emily, symbolised, elwes, ficino, jumbo, rhetoric, ashton,
# Nearest to for: cavan, dirt, gallus, vernet, ayyavazhi, flatness, agreeing, sandinista,
# Nearest to many: talleyrand, tending, converges, ethnologue, uploads, abeyance, fertility, hazard,
# Nearest to new: farming, direct, prewar, mnemonics, noteworthy, cnt, impeach, gridiron,
# Nearest to all: uns, prokaryotic, waring, sadie, rubin, laureate, ramsay, lionhead,
# Nearest to his: fragrant, hmg, sheikh, parliaments, bottle, deficit, cleanse, mathews,
# Nearest to united: junit, iguana, tocantins, elas, ehud, zolt, hamsters, autosomal,
# Nearest to that: missy, devoting, stole, willows, germs, glissando, bulge, ether,
# Nearest to these: unarable, tribal, caret, reynolds, lovingly, volta, resh, shake,
# Nearest to was: sins, foray, stimulating, colloquial, melatonin, bacterium, treason, refit,
# Nearest to were: frustrations, theorised, reyes, systematized, squeezed, js, trout, lerner,
# Average loss at step 2000: 4.503740
# Average loss at step 4000: 4.113991
# Average loss at step 6000: 3.915574
# Average loss at step 8000: 3.917697
# Average loss at step 10000: 3.883896
# Nearest to years: rafael, affluent, motherboards, parallelism, duarte, case, city, disestablished,
# Nearest to no: flowing, gravis, a, roads, intact, conte, sten, franchising,
# Nearest to will: grateful, baskerville, to, derived, bypasses, cer, arecibo, cathode,
# Nearest to may: would, commanders, nomad, ortho, agp, joris, surnames, tenn,
# Nearest to and: in, with, UNK, of, by, the, malleus, concise,
# Nearest to also: surnames, groceries, stravinsky, oaths, symbolised, actually, naphtali, cabral,
# Nearest to for: bony, of, with, otc, castles, lunda, huntingford, affinities,
# Nearest to many: these, masts, uploads, drab, most, fertility, movements, talleyrand,
# Nearest to new: biodiesel, gridiron, farming, tli, mnemonics, realism, afterward, noteworthy,
# Nearest to all: lionhead, front, waring, sedimentary, know, curtis, were, hatta,
# Nearest to his: this, the, aortic, strassman, obelisk, their, its, bartolom,
# Nearest to united: junit, iguana, autosomal, rustic, elas, hamsters, fascists, universe,
# Nearest to that: what, this, pauline, newer, which, waldemar, considers, suspend,
# Nearest to these: many, unarable, unchallenged, tribal, shake, caret, there, executes,
# Nearest to was: is, barriers, were, bulletin, fringe, disambiguation, cysteine, convocation,
# Nearest to were: are, was, js, is, partners, pindar, persepolis, house,
# Average loss at step 12000: 3.861565
# Average loss at step 14000: 3.844543
# Average loss at step 16000: 3.733932
# Average loss at step 18000: 3.818152
# Average loss at step 20000: 3.796258
# Nearest to years: rafael, disestablished, goalkeeper, parallelism, balkh, motherboards, leo, affluent,
# Nearest to no: flowing, roads, baggage, sten, cephalon, stack, something, pillaging,
# Nearest to will: grateful, bypasses, baskerville, cer, arecibo, would, bookstores, chelsea,
# Nearest to may: would, can, could, should, dandyism, unspecified, arbroath, commanders,
# Nearest to and: by, of, in, barbiturates, or, s, UNK, american,
# Nearest to also: diagnosed, arran, matisse, symbolised, rigs, thalberg, limburg, futurama,
# Nearest to for: with, wco, telecom, delft, malleus, dien, hohner, waas,
# Nearest to many: some, these, most, all, drab, other, masts, were,
# Nearest to new: gridiron, noteworthy, biodiesel, farming, afterward, pontchartrain, synthesizing, direct,
# Nearest to all: many, these, ramsay, some, cpus, several, iib, waring,
# Nearest to his: their, the, its, s, her, a, strassman, stockpiles,
# Nearest to united: side, ericales, iguana, autosomal, elas, inositol, deformation, rustic,
# Nearest to that: which, maori, this, athletics, gesserit, quechua, but, paddock,
# Nearest to these: many, some, other, they, all, kemp, their, there,
# Nearest to was: is, were, had, are, has, been, translucent, be,
# Nearest to were: are, was, have, is, vetoes, many, prasad, pindar,
# Average loss at step 22000: 3.728207
# Average loss at step 24000: 3.783113
# Average loss at step 26000: 3.630651
# Average loss at step 28000: 3.591401
# Average loss at step 30000: 3.631901
# Nearest to years: goalkeeper, rafael, disestablished, year, think, alle, swami, trench,
# Nearest to no: roads, uninterrupted, stack, much, finding, photosphere, modified, little,
# Nearest to will: can, would, to, grateful, may, bypasses, chosen, mileva,
# Nearest to may: can, would, should, could, rupture, mash, willing, knuckle,
# Nearest to and: or, of, like, competitors, but, from, while, satisfaction,
# Nearest to also: which, diagnosed, phrases, modularity, visicalc, dendritic, russ, abortions,
# Nearest to for: dama, indeed, during, gneiss, with, eisa, ayyavazhi, of,
# Nearest to many: some, several, these, other, all, most, goblin, masts,
# Nearest to new: gridiron, biodiesel, connotations, synthesizing, papuan, discord, everlast, evangelion,
# Nearest to all: many, some, several, these, ramsay, were, dei, match,
# Nearest to his: their, its, her, s, the, these, this, strassman,
# Nearest to united: side, inositol, ericales, autosomal, fascists, end, moniker, elas,
# Nearest to that: which, what, athletics, illa, this, piccolo, when, sober,
# Nearest to these: other, many, some, his, their, all, each, those,
# Nearest to was: is, were, became, monthly, had, has, are, hiroshi,
# Nearest to were: are, was, been, had, is, ramsay, disparagingly, all,
# Average loss at step 32000: 3.665461
# Average loss at step 34000: 3.740847
# Average loss at step 36000: 3.683106
# Average loss at step 38000: 3.717898
# Average loss at step 40000: 3.679875
# Nearest to years: year, goalkeeper, disestablished, tricolor, think, rafael, unisys, prophesies,
# Nearest to no: any, a, finding, photosphere, roads, stack, an, flowing,
# Nearest to will: would, can, may, could, to, arecibo, should, bookstores,
# Nearest to may: can, would, could, should, will, might, must, willing,
# Nearest to and: or, with, including, in, but, liberties, refrigerators, amaranthus,
# Nearest to also: which, middleton, haag, that, malawian, although, luncheon, vert,
# Nearest to for: hohner, of, saving, revolved, bertha, obsessive, hapless, from,
# Nearest to many: some, several, these, other, all, most, both, were,
# Nearest to new: superscription, gridiron, biodiesel, synthesizing, existing, papuan, everlast, manufacturers,
# Nearest to all: many, some, these, several, different, invalidated, moines, osteoporosis,
# Nearest to his: her, their, its, latte, the, lizzy, humboldt, mahmoud,
# Nearest to united: inositol, states, ericales, holocaust, granting, elas, fascists, moniker,
# Nearest to that: which, however, because, also, athletics, challenging, this, who,
# Nearest to these: many, other, some, several, all, both, they, those,
# Nearest to was: is, were, has, had, became, be, disconnect, axis,
# Nearest to were: are, was, have, is, be, had, many, several,
# Average loss at step 42000: 3.679859
# Average loss at step 44000: 3.705519
# Average loss at step 46000: 3.671311
# Average loss at step 48000: 3.748447
# Average loss at step 50000: 3.649415
# Nearest to years: year, days, months, think, vocalic, goalkeeper, tricolor, balkh,
# Nearest to no: any, little, finding, roads, photosphere, petersen, leather, neurotransmitters,
# Nearest to will: would, can, may, could, should, to, must, bookstores,
# Nearest to may: can, would, could, will, should, might, must, does,
# Nearest to and: with, of, or, in, but, s, under, his,
# Nearest to also: which, now, often, sometimes, been, thereabouts, although, goats,
# Nearest to for: of, during, after, ccf, without, when, to, comprehension,
# Nearest to many: some, several, these, all, other, both, most, those,
# Nearest to new: synthesizing, gridiron, york, orchard, everlast, va, evangelion, superscription,
# Nearest to all: many, some, several, these, glengarry, tailed, different, valiantly,
# Nearest to his: her, their, the, s, its, him, life, a,
# Nearest to united: states, fascists, nobel, veracity, elas, laughlin, inositol, moniker,
# Nearest to that: which, however, when, if, because, but, this, what,
# Nearest to these: they, some, many, several, other, both, all, their,
# Nearest to was: is, were, had, became, are, being, has, typography,
# Nearest to were: are, was, had, ramsay, being, have, backslash, many,
# Average loss at step 52000: 3.667597
# Average loss at step 54000: 3.756700
# Average loss at step 56000: 3.728460
# Average loss at step 58000: 3.666476
# Average loss at step 60000: 3.718841
# Nearest to years: year, days, months, trench, goalkeeper, memoirs, disestablished, billion,
# Nearest to no: any, a, finding, still, this, that, neurotransmitters, photosphere,
# Nearest to will: would, can, could, may, should, must, to, might,
# Nearest to may: can, would, could, should, will, might, must, does,
# Nearest to and: or, while, but, with, to, in, when, reassessment,
# Nearest to also: now, which, although, sometimes, goats, often, been, that,
# Nearest to for: or, without, sibelius, marseillaise, jurisprudence, rationalism, ayyavazhi, as,
# Nearest to many: some, several, these, all, most, both, those, various,
# Nearest to new: synthesizing, compatriots, gridiron, york, orchard, labour, allows, single,
# Nearest to all: these, many, are, several, some, different, other, invalidated,
# Nearest to his: her, their, its, him, life, austria, our, my,
# Nearest to united: states, fascists, nobel, moniker, ehud, ericales, inositol, radcliffe,
# Nearest to that: which, however, if, although, what, while, when, because,
# Nearest to these: some, other, many, all, both, their, several, different,
# Nearest to was: is, were, became, been, had, has, being, subway,
# Nearest to were: are, was, be, ramsay, been, have, many, being,
# Average loss at step 62000: 3.688744
# Average loss at step 64000: 3.716753
# Average loss at step 66000: 3.528125
# Average loss at step 68000: 3.498442
# Average loss at step 70000: 3.686093
# Nearest to years: year, months, days, trench, decades, centuries, died, witches,
# Nearest to no: any, still, finding, only, this, every, a, neurotransmitters,
# Nearest to will: would, can, could, may, should, must, to, might,
# Nearest to may: can, would, will, could, should, might, must, does,
# Nearest to and: but, while, when, in, or, with, on, which,
# Nearest to also: now, often, which, sometimes, usually, annihilate, abeda, incremental,
# Nearest to for: when, or, as, at, of, if, longitudinal, chestnut,
# Nearest to many: some, several, these, all, various, those, both, most,
# Nearest to new: gridiron, synthesizing, orchard, existing, rips, integrating, cerium, compatriots,
# Nearest to all: many, several, various, these, other, some, both, thoreau,
# Nearest to his: their, her, its, the, a, him, s, my,
# Nearest to united: states, ericales, fascists, nobel, radcliffe, elas, inositol, bankhead,
# Nearest to that: which, this, if, where, while, cayman, what, challenging,
# Nearest to these: many, several, other, some, their, they, both, those,
# Nearest to was: is, were, became, has, had, being, been, be,
# Nearest to were: are, was, be, been, ramsay, being, have, many,
# Average loss at step 72000: 3.602346
# Average loss at step 74000: 3.693987
# Average loss at step 76000: 3.605691
# Average loss at step 78000: 3.723342
# Average loss at step 80000: 3.649596
# Nearest to years: year, months, days, decades, centuries, period, hundred, weeks,
# Nearest to no: any, a, this, little, only, still, every, another,
# Nearest to will: could, would, can, may, must, should, might, cannot,
# Nearest to may: can, will, would, could, should, might, must, cannot,
# Nearest to and: including, or, liberties, amaranthus, include, UNK, while, undercover,
# Nearest to also: which, often, now, sometimes, where, thereabouts, usually, abeda,
# Nearest to for: including, artisans, of, during, after, as, corneille, ossie,
# Nearest to many: several, some, all, these, various, those, both, most,
# Nearest to new: gridiron, kansas, york, connolly, synthesizing, modern, absentia, existing,
# Nearest to all: many, several, these, some, each, different, both, various,
# Nearest to his: their, her, its, s, the, my, paternal, him,
# Nearest to united: states, radcliffe, nobel, ericales, uk, elas, fascists, allusions,
# Nearest to that: which, however, but, if, although, while, this, what,
# Nearest to these: some, many, other, several, all, both, their, various,
# Nearest to was: is, became, were, had, are, has, being, cgi,
# Nearest to were: are, was, be, had, have, ramsay, became, been,
# Average loss at step 82000: 3.693677
# Average loss at step 84000: 3.637451
# Average loss at step 86000: 3.635373
# Average loss at step 88000: 3.566020
# Average loss at step 90000: 3.576385
# Nearest to years: year, days, months, decades, period, weeks, hundred, witches,
# Nearest to no: any, only, this, every, useless, offenders, little, neurotransmitters,
# Nearest to will: could, would, can, must, should, may, cannot, might,
# Nearest to may: can, would, could, should, will, must, might, cannot,
# Nearest to and: while, including, but, of, or, in, by, alexey,
# Nearest to also: which, often, now, still, russ, augustan, abeda, however,
# Nearest to for: including, without, rationalism, gave, from, throughout, through, hohner,
# Nearest to many: some, several, various, both, all, these, those, most,
# Nearest to new: existing, synthesizing, gridiron, old, everlast, york, viet, kashrut,
# Nearest to all: many, several, these, some, both, other, any, various,
# Nearest to his: their, her, its, the, both, s, my, him,
# Nearest to united: nobel, states, radcliffe, ericales, fascists, elas, baldr, inositol,
# Nearest to that: which, this, however, although, but, what, because, welded,
# Nearest to these: both, some, many, other, different, various, several, all,
# Nearest to was: is, were, became, had, been, are, has, being,
# Nearest to were: are, was, had, been, have, be, ramsay, several,
# Average loss at step 92000: 3.651340
# Average loss at step 94000: 3.684252
# Average loss at step 96000: 3.636756
# Average loss at step 98000: 3.709766
# Average loss at step 100000: 3.654844
# Nearest to years: days, year, months, decades, hundred, weeks, period, centuries,
# Nearest to no: any, only, little, a, offenders, horch, metropolises, useless,
# Nearest to will: would, could, can, must, should, might, may, cannot,
# Nearest to may: can, would, should, could, must, will, might, does,
# Nearest to and: while, or, choreographer, including, but, with, armando, druidic,
# Nearest to also: sometimes, now, where, which, still, russ, often, that,
# Nearest to for: of, gneiss, after, wrongdoing, toonami, before, against, dragoon,
# Nearest to many: several, some, various, most, all, these, those, both,
# Nearest to new: york, gridiron, old, religionfacts, synthesizing, kansas, sof, cyclic,
# Nearest to all: many, several, both, other, various, some, every, these,
# Nearest to his: their, her, its, my, s, the, dew, finalized,
# Nearest to united: states, fascists, radcliffe, nobel, hsbc, commonwealth, troubling, deformation,
# Nearest to that: however, which, although, what, cayman, if, paddock, piccolo,
# Nearest to these: various, several, both, many, those, different, numerous, other,
# Nearest to was: is, were, became, had, be, has, being, chloroform,
# Nearest to were: are, was, had, have, is, ramsay, been, be,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
